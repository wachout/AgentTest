# %% [markdown]
# # LightRAG and LangGraph Agent: Testing and Documentation

# %% [markdown]
# This notebook demonstrates the complete workflow of the LightRAG and LangGraph agent. We will walk through the following steps:
# 1. **Data Ingestion**: Loading the data and creating the dual-structure index (vector and knowledge graph).
# 2. **LangGraph Workflow**: Executing the multi-step agent to answer a query.
# 3. **Visualization**: Visualizing the retrieved documents and the generated response.

# %% [markdown]
# ## 1. Data Ingestion

# %%
# %pip install -r requirements.txt

# %%
from ingest import ingest_data
ingest_data()

# %% [markdown]
# ## 2. LangGraph Workflow

# %%
from src.agent import app
from langchain_core.messages import HumanMessage

# %%
query = "Who is Dr. Liu?"
inputs = {"messages": [HumanMessage(content=query)]}
for output in app.stream(inputs):
    for key, value in output.items():
        print(f"Output from node '{key}':")
        print("---")
        print(value)
    print("\n---\n")

# %% [markdown]
# ## 3. Visualization

# %%
import pandas as pd

final_state = app.invoke(inputs)

print("--- Final Generation ---")
print(final_state.get('generation'))

if final_state.get('reranked_documents'):
    print("\n--- Retrieved Documents ---")
    df = pd.DataFrame(final_state['reranked_documents'])
    display(df)
